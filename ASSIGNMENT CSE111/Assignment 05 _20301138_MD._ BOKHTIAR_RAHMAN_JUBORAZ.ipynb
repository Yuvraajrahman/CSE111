# %%
#CSE111 ASSIGNMENT 05, FALL 2020
#NAME : MD BOKHTIAR RAHMAN JUBORAZ
#ID : 20301138
#SECTION :O4

# %%
#SOLUTION NO.1
class Marks:
    def __init__(self, mark):
        self.mark = mark

    def __add__(self, other):
        return Marks(self.mark + other.mark)




Q1 = Marks(int(input("Quiz 1 (out of 10): ")))
Q2 = Marks(int(input("Quiz 2 (out of 10): ")))
Lab = Marks(int(input("Lab (out of 30): ")))
Mid = Marks(int(input("Mid (out of 20): ")))
Final = Marks(int(input("Final (out of 30): ")))
total = Q1 + Q2 + Lab + Mid + Final
print("Total marks: {}".format(total.mark))
# Out:
# Quiz 1 (out of 10): 10
# Quiz 2 (out of 10): 10
# Lab (out of 30): 10
# Mid (out of 20): 10
# Final (out of 30): 10
# Total marks: 50

# %%
#SOLUTION N0.02
class Teacher:
    def __init__(self, __name, __department):


        self.__name = __name
        self.__department = __department

    def addCourse(self, __x):
        self.x = __x




    def printDetail(self):
        print('===========================')
        print('Name:', self.__name)
        print('Department:', self.__department)
        print('List of courses')
        print('============================')
        print(self.x)



class Course():
    def __init__(self, sub):
        self.sub = sub

    def __str__(self):
        return self.sub


t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CCSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: CSE
# List of courses
# ...
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: CSE
# List of courses
# ...
# CCSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department: CSE
# List of courses
# ...
# CSE 340 Computer Architecture

# %%
#solution no.03

#first_class
class Team:
    def __init__(self, team=''):
        self.team = team

    def setName(self, t1):
        self.team = t1

    def printDetail(self):
        
        print("=====================")
        print('Team:', self.team)
        print('List of Players:')
        print(self.name)
        print("=====================")

    def addPlayer(self, other):
        self.name = other

#second_class
class Player:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return self.name
    


b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of Players:
# Tamim
# ...
# Team: Australia
# List of Players:
# Lee
# ...

# %%
#solution no.04
class Color:
    def __init__(self, clr):
        self.clr = clr
    def __add__(self, obj):
        if self.clr == "red" and obj.clr== "yellow":
            clr ="Orange"
            newobj = Color(clr)
            return newobj
        elif self.clr == "red" and obj.clr== "blue":
            clr ="Violet"
            newobj = Color(clr)
            return newobj
        elif self.clr == "yellow" and obj.clr== "blue":
            clr ="Green"
            newobj = Color(clr)
            return newobj





C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)
# Out:
# First Color: yellow
# Second Color: BLue
# Color formed: Green

# %%
#SOLUTION NO.O5
class Circle:
    def __init__(self, n ):
        self.__num = n


    def getRadius(self):
        return self.__num


    def area(self):
        area1 = 3.141592653589793125 * (self.__num * self.__num)
        return area1


    def __add__(self, other):
        self.__num = self.__num + other.__num

        return self


c1 = Circle(4)
print("First circle radius:", c1.getRadius())
print("First circle area:", c1.area())
c2 = Circle(5)
print("Second circle radius:", c2.getRadius())
print("Second circle area:", c2.area())
c3 = c1 + c2
print("Third circle radius:", c3.getRadius())
print("Third circle area:", c3.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483
# Third circle radius: 9
# Third circle area: 254.46900494077323

# %%
#solution no. 06 
class Triangle:
    def __init__(self, base, height):
        self.height = height
        self.base = base



    def getHeight(self):
        return self.height


    def getBase(self):
        return self.base



    def area(self):
        a = 0.5 * self.base * self.height
        return a


    def __sub__(self, other):
        self.base = self.base - other.base
        self.height = self.height - other.height
        return self


t1 = Triangle(10, 5)
print("First Triangle Base:", t1.getBase())
print("First Triangle Height:", t1.getHeight())
print("First Triangle area:", t1.area())
t2 = Triangle(5, 3)
print("Second Triangle Base:", t2.getBase())
print("Second Triangle Height:", t2.getHeight())
print("Second Triangle area:", t2.area())
t3 = t1 - t2
print("Third Triangle Base:", t3.getBase())
print("Third Triangle Height:", t3.getHeight())
print("Third Triangle area:", t3.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5
# Third Triangle Base: 5
# Third Triangle Height: 2
# Third Triangle area: 5.0

# %%
#solution no.07
class Dolls:
    def __init__(self, n, p):

        self.name = n
        self.price = p

    def detail(self):
        return f'Doll:{self.name} \nPrice:{self.price} taka'


    def __gt__(self, obj):
        if self.price > obj.price:
            return True
        else:
            return False



    def __add__(self, obj):
        self.price = self.price + obj.price
        self.name = self.name + ' ' + obj.name
        return self




obj_1 = Dolls("Tweety", 2500)
print(obj_1.detail())
if obj_1 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_2 = Dolls("Daffy Duck", 1800)
print(obj_2.detail())
if obj_2 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_3 = Dolls("Bugs Bunny", 3000)
print(obj_3.detail())
if obj_3 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_4 = Dolls("Porky Pig", 1500)
print(obj_4.detail())
if obj_4 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_5 = obj_2 + obj_3
print(obj_5.detail())
if obj_5 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
# Out:
# Doll:Tweety
# Price:2500 taka
# Thank you!
# ...
# Doll:Daffy Duck
# Price:1800 taka
# Thank you!
# ...
# Doll:Bugs Bunny
# Price:3000 taka
# Congratulations! You get the Tweety as a gift!
# ...
# Doll:Porky Pig
# Price:1500 taka
# Thank you!
# ...
# Doll:Daffy Duck Bugs Bunny
# Price:4800 taka
# Congratulations! You get the Tweety as a gift!

# %%
#solution no.08
class Coordinates():
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2


    def __sub__(self, other):
        self.val1 = self.num1 - other.num1
        self.val2 = self.num2 - other.num2
        return self

    def __mul__(self, x):
        self.val1 = self.num1 * x.num1
        self.val2 = self.num2 * x.num2

        return self


    def detail(self):

        return f"({self.val1},{self.val2})"

    def __eq__(self, other):
        if self.num1 == self.num2:
            return "The calculated coordinates are the same."
        else:
            return "The calculated coordinates are NOT the same."


p1 = Coordinates(int(input()), int(input()))
p2 = Coordinates(int(input()), int(input()))
p4 = p1 - p2
print(p4.detail())
p5 = p1 * p2
print(p5.detail())
point_check = (p4 == p5)
print(point_check)
# Out:
# 1
# 2
# 3
# 4
# (-2,-2)
# (3,8)
# The calculated coordinates are NOT the same.
